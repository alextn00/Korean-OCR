# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = load_model('../model/KoreanOCR_ver3.h5')

# %%
path = "../dataset/split_data/train/"
print(len(os.listdir(path)))
# Out:
# 2350

# %%
class_list = os.listdir(path)
class_list
# Out:
# ['가',
#  '각',
#  '간',
#  '갇',
#  '갈',
#  '갉',
#  '갊',
#  '감',
#  '갑',
#  '값',
#  '갓',
#  '갔',
#  '강',
#  '갖',
#  '갗',
#  '같',
#  '갚',
#  '갛',
#  '개',
#  '객',
#  '갠',
#  '갤',
#  '갬',
#  '갭',
#  '갯',
#  '갰',
#  '갱',
#  '갸',
#  '갹',
#  '갼',
#  '걀',
#  '걋',
#  '걍',
#  '걔',
#  '걘',
#  '걜',
#  '거',
#  '걱',
#  '건',
#  '걷',
#  '걸',
#  '걺',
#  '검',
#  '겁',
#  '것',
#  '겄',
#  '겅',
#  '겆',
#  '겉',
#  '겊',
#  '겋',
#  '게',
#  '겐',
#  '겔',
#  '겜',
#  '겝',
#  '겟',
#  '겠',
#  '겡',
#  '겨',
#  '격',
#  '겪',
#  '견',
#  '겯',
#  '결',
#  '겸',
#  '겹',
#  '겻',
#  '겼',
#  '경',
#  '곁',
#  '계',
#  '곈',
#  '곌',
#  '곕',
#  '곗',
#  '고',
#  '곡',
#  '곤',
#  '곧',
#  '골',
#  '곪',
#  '곬',
#  '곯',
#  '곰',
#  '곱',
#  '곳',
#  '공',
#  '곶',
#  '과',
#  '곽',
#  '관',
#  '괄',
#  '괆',
#  '괌',
#  '괍',
#  '괏',
#  '광',
#  '괘',
#  '괜',
#  '괠',
#  '괩',
#  '괬',
#  '괭',
#  '괴',
#  '괵',
#  '괸',
#  '괼',
#  '굄',
#  '굅',
#  '굇',
#  '굉',
#  '교',
#  '굔',
#  '굘',
#  '굡',
#  '굣',
#  '구',
#  '국',
#  '군',
#  '굳',
#  '굴',
#  '굵',
#  '굶',
#  '굻',
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import random
from PIL import Image

selected_folder = random.choice(class_list)
selected_path = path + selected_folder + '/'
selected = os.listdir(selected_path)

random_image = random.choice(selected)
img = Image.open(selected_path + random_image)
plt.imshow(img)

# %%
img = image.load_img(selected_path + random_image, target_size=(32, 32))
img = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

print('Prob : ', np.max(prediction[0], axis = -1))
predicted_class = class_list[np.argmax(prediction[0], axis = -1)]
print('Classified : ', predicted_class, '\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title('loaded image')
# Out:
# 1/1 [==============================] - 0s 163ms/step
# Prob :  1.0
# Classified :  듈
# Text(0.5, 1.0, 'loaded image')

# %%
test_image = '../test_image/갊.png'
img = Image.open(test_image)
plt.imshow(img)

# %%
img = image.load_img(test_image, target_size=(32, 32))
img = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

print('Prob : ', np.max(prediction[0], axis = -1))
predicted_class = class_list[np.argmax(prediction[0], axis = -1)]
print('Classified : ', predicted_class, '\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title('loaded image')
# Out:
# 1/1 [==============================] - 0s 198ms/step
# Prob :  0.99998975
# Classified :  뉼
# Text(0.5, 1.0, 'loaded image')
